# %% [markdown]
# <a href="https://colab.research.google.com/github/tirolezzo/DataScience/blob/main/GraficosVisualiza%C3%A7%C3%A3oDashboards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Teoria

# %% [markdown]
# Na ciência de dados, no processo de dados em informação e conheicmento, a visualização é uma parte critica.
#
# sem ela, não se tem resultado, não se chega ao objetivo do trabalho, não se pode contar a história... não da para demonstrar o que aconteceu.
#
# Arte ou Ciência?   95% Ciência e 5% Talento
#  * A visualização de dados é acima de tudo uma ciência, e por isso funciona melhor com a aplicação de boas práticas.
#
# Durante a Análise Exploratória:
#  * Relações
#  * Limites
#  * Outliers
#  * Tendências
#  * Padrões
#
# Durante a fase Explanatória:
#  * Conslusões
#  * Evidências
#  * Sofisticação
#
#
# A visualização de dados pode produzir diversos tipos de artefatos:
#  * Gráficos estáticos: é uma representação instantânea de um conjunto de dados
#  * Dashboards: conjunto de gráficos interativos e exibidos em conjunto
#  * Infográficos: Gráficos mais ricos visualmente, porém não estão vinculados diretamwente a uma fonte de dados.

# %% [markdown]
# # Dicas para Criar Dashboards

# %% [markdown]
# 1. Comparado ao que?
# 2. Bom ou Ruim?
# 3. Métricas Corretas?
# 4. Temas
# 5. Tamanho e Resolução
# 6. Melhores e Piores
# 7. Excesso ou falta de níveis
# 8. Proporção
#
# Formas de Organizar a Informação
#
# * Localização
# * Alfabeticamnente
# * Tempo
# * Categoria
# * Hierárquia
#
# Percepção: capacidade de perceber corretamente as relações entre as variáveis. O gráfico deve maximizar a apreensão das relações entre as variáveis.
#
# Clareza: Capacidade de distinguir visualmente os elementos de um gráfico. Os elementos ou relações mais importantes devem ter destaque.
#
# Consistência: capacidade de interpretar um gráfico com base na semelhança com gráficos anteriores. Os elementos, forma de simbolos e cores devem ser consistentes com a utilizada em gráficos anteriores.
#
# Eficiência: Capacidade de demonstrar uma relação complexa de forma simples. Os elementos do gráfico devem ser utilizados racionamento e o gráfico deve ser de fácil interpretação.
#
# Necessidade: O gráfico e seus elementos são necessários? O gráfico é a melhor forma de representar os dados comparados com as alternativas, como tabelas ou texto?
#
# Veracidade: capacidade de determinar o valor representado pelos elementos gráficos em relação a escala. Os elementos gráficos devem ser posicionados e dimensionados com precisão.
#
# Dicas:
# 1. Evitar gráficos de setores
# 2. Evitar 3D
# 3. Cores não ordenam valores. Escalas cinza sim.
# 4. Devem mostrar 20 números ou menos
# 5. Variar dados, não design
# 6. gráficos devem destacar dados, não design
# 7. Evitar linhas de grade
# 8. Não usaar more vibration
#
# Daltonismo
#
# - Considere que 7% da população possui algum tipo de daltonismo
# - Considerar palhetas de cores adequadas neste caso

# %% [markdown]
# # Capacidade de percepção do cérebro

# %% [markdown]
# * Gráfico de barras
# * Gráfico de Setores
# * Gráfico de Dispersão
# *
# *
#
# - Gráfico de linhas: Dados contínuos, Evolução, Series temporais, com o tempo no eixo horizontal dimensõpes no vertical e Suporta várias categorias
# - Dispersão: Mostrar a relação entre viriáveis, Bubble Chart: Terceira Dimensão, Cor: Categoria

# %% [markdown]
# # Prática Histograma

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/trees.csv')

# %%
base = pd.read_csv(url)
base.shape
# Out:
# (31, 3)

# %%
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Creation of the histogram, considering only the second attribute the database and with two divisions (bins)
# The variable 'h' stores the ranges of height values

h= np.histogram(base.iloc[:, 1], bins = 6)
h
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
# Histogram display with 6 divisions (bins)
plt.hist(base.iloc[:, 1], bins = 6)
plt.title("Árvores")
plt.ylabel('Frequencia')
plt.xlabel('Altura')
# Out:
# Text(0.5, 0, 'Altura')

# %%
import seaborn as sns

# %%
# Histogram with 10 divisions (bins) and only for the first attribute of the database
plt.hist(base.iloc[:, 1], bins = 10)
# Out:
# (array([3., 1., 2., 3., 2., 6., 2., 8., 1., 3.]),
#  array([63. , 65.4, 67.8, 70.2, 72.6, 75. , 77.4, 79.8, 82.2, 84.6, 87. ]),
#  <BarContainer object of 10 artists>)

# %%
# Histogram with the frequency distribution line, with 6 divisions (bins)
# kde = density line
sns.histplot(base.iloc[:,1], kde = False , bins = 6,  palette="light:m_r").set(title='Arvores')
# Out:
# <ipython-input-144-22278cddea6e>:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(base.iloc[:,1], kde = False , bins = 6,  palette="light:m_r").set(title='Arvores')
# [Text(0.5, 1.0, 'Arvores')]

# %% [markdown]
# # Prática Gráfico com linha de densidade

# %%
# density, kdeplot method for density
sns.kdeplot(base.iloc[:,1],  palette="light:m_r").set(title='Arvores')
# Out:
# <ipython-input-145-539621454309>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(base.iloc[:,1],  palette="light:m_r").set(title='Arvores')
# [Text(0.5, 1.0, 'Arvores')]

# %%
# density and histogram
sns.histplot(base.iloc[:,1], kde = True , bins = 6,  palette="light:m_r").set(title='Árvores')
# Out:
# <ipython-input-146-6baed273828b>:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(base.iloc[:,1], kde = True , bins = 6,  palette="light:m_r").set(title='Árvores')
# [Text(0.5, 1.0, 'Árvores')]

# %% [markdown]
# # Prática com gráfico de dispersão

# %%
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# scatter plot considering volume and dispersion
plt.scatter(x = base.Girth, y = base.Volume, color = 'blue', facecolors = 'none', marker = '*')
plt.title('Árvores')
plt.xlabel('Circunferencia')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
# line chart considering the volume and the attribute 'Girth'. without marker
plt.plot(base.Girth, base.Volume)
plt.title('Árvores')
plt.xlabel('Circunferencia')
plt.ylabel('Volume')
# Out:
# Text(0, 0.5, 'Volume')

# %%
# scatter plot with data 'jitter'
# fit_reg # trend line
sns.regplot(x = base.Girth, y = base.Volume, data = base, x_jitter = 0.3, fit_reg = True)
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>

# %%
#creating two variables for each attribute (x = conc and y = uptake)
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/co2.csv')
base = pd.read_csv(url)
base.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
base.shape
# Out:
# (84, 5)

# %%
x = base.conc
y = base.uptake

# %%
# returns the unique values of the attribute 'treatment'
unicos = list(set(base.Treatment))
unicos
# Out:
# ['nonchilled', 'chilled']

# %%
# runs through each treatment type (chilled and nonchilled) and creates a scatter plot
for i in range (len(unicos)):
  indice = base.Treatment == unicos[i]
  plt.scatter(x[indice], y[indice], label = unicos[i])
plt.legend(loc = 'lower right')

# %% [markdown]
# # Divisão da Tela (SubGráficos)

# %%
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/trees.csv')
base = pd.read_csv(url)
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Girth with Volume
plt.scatter(base.Girth, base.Volume)

# %%
#Girth with Height
plt.scatter(base.Girth, base.Height)

# %%
# Height with Volume
plt.scatter(base.Height, base.Volume, marker = '*')

# %%
# volume histogram
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
# printing together
# Creating the figure, on which the graphics will be positioned

plt.figure(1)
plt.subplot(2, 2, 1)
plt.scatter(base.Girth, base.Volume)

plt.subplot(2, 2, 2)
plt.scatter(base.Girth, base.Height)

plt.subplot(2, 2, 3)
plt.scatter(base.Height, base.Volume, marker = '*')

plt.subplot(2, 2, 4)
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Boxplot

# %%
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/trees.csv')
base = pd.read_csv(url)
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# boxplot generation
# patch_artist = True preenche, showfliers outliers

plt.boxplot(base.Volume, vert = False, showfliers = False, notch = True, patch_artist = True)
plt.title('Árvores')
plt.xlabel('Volume')
# Out:
# Text(0.5, 0, 'Volume')

# %%
# data per row
plt.boxplot(base)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %%
# generation of 3 boxplots, each showing different information
plt.boxplot(base.Volume , vert = False)
plt.boxplot(base.Girth , vert = False)
plt.boxplot(base.Height , vert = False)
plt.title('Árvores')
plt.xlabel('Dados')
# Out:
# Text(0.5, 0, 'Dados')

# %% [markdown]
# # Gráficos de Barras e setores

# %%
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/insect.csv')
base = pd.read_csv(url)
base.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
base.shape
# Out:
# (72, 2)

# %%
# Grouping the data based on the 'spray' attribute, counting and adding up the records
agrupado = base.groupby(['spray'])['count'].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
# bar chart
agrupado.plot.bar(color = 'gray')
# Out:
# <Axes: xlabel='spray'>

# %%
# colors
agrupado.plot.bar(color = ['blue', 'yellow', 'red', 'green', 'pink', 'orange'])
# Out:
# <Axes: xlabel='spray'>

# %%
# graph pizza
agrupado.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
agrupado.plot.pie(legend = True)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Boxplot com Seaborn

# %%
import seaborn as srn

# %%
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/trees.csv')
base = pd.read_csv(url)
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# visualization of a boxplot
srn.boxplot(data = base.Volume, orient = 'v').set_title("Árvores")
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
# visualization of several boxplots in the same image
srn.boxplot(data = base)
# Out:
# <Axes: >

# %% [markdown]
# # Histogramas e Densidade com Seaborn

# %%
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/chicken.csv')
base = pd.read_csv(url)
base.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
base.shape
# Out:
# (71, 2)

# %%
# creation of a new dataframe grouping the 'feed' attribute
agrupado = base.groupby(['feed'])['weight'].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# new dataframe only to test Pandas filters
teste = base.loc[base['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
# Histogram considering only the 'horsebean' value
# Only the density graph in this case
srn.kdeplot(base.loc[base['feed'] == 'horsebean'].weight).set(title = 'horsebean')
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
# Histogram considering only the 'casein' value
srn.histplot(base.loc[base['feed'] == 'casein'].weight, kde = True).set(title = 'casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
# Histogram considering only the 'linseed' value
# srn.distplot(base.loc[base['feed'] == 'linseed'].weight).set_title('linseed')
srn.histplot(base.loc[base['feed'] == 'linseed'].weight, kde = True).set(title = 'linseed')
# Out:
# [Text(0.5, 1.0, 'linseed')]

# %%
# Histogram considering only the 'meatmeal' value
srn.histplot(base.loc[base['feed'] == 'meatmeal'].weight, kde = True).set(title = 'meatmeal')
# Out:
# [Text(0.5, 1.0, 'meatmeal')]

# %%
# Histogram considering only the 'soybean' value
srn.histplot(base.loc[base['feed'] == 'soybean'].weight, kde = True).set(title = 'soybean')
# Out:
# [Text(0.5, 1.0, 'soybean')]

# %%
# Histogram considering only the 'sunflower' value
srn.histplot(base.loc[base['feed'] == 'sunflower'].weight, kde = True).set(title = 'sunflower')
# Out:
# [Text(0.5, 1.0, 'sunflower')]

# %%
# 2 x 3 graphic printout - 3 rows 2 columns
plt.figure()
plt.subplot(3, 2, 1)
srn.histplot(base.loc[base['feed'] == 'horsebean'].weight, kde = True).set(title = 'horsebean')
plt.subplot(3, 2, 2)
srn.histplot(base.loc[base['feed'] == 'casein'].weight, kde = True).set(title = 'casein')
plt.subplot(3, 2, 3)
srn.histplot(base.loc[base['feed'] == 'linseed'].weight, kde = True).set(title = 'linseed')
plt.subplot(3, 2, 4)
srn.histplot(base.loc[base['feed'] == 'meatmeal'].weight, kde = True).set(title = 'meatmeal')
plt.subplot(3, 2, 5)
srn.histplot(base.loc[base['feed'] == 'soybean'].weight, kde = True).set(title = 'soybean')
plt.subplot(3, 2, 6)
srn.histplot(base.loc[base['feed'] == 'sunflower'].weight, kde = True).set(title = 'sunflower')

# adjusts the layout so there is no overlap
plt.tight_layout()

# %%
# 2 x 3 graphic printout - 3 rows 2 columns
plt.figure()
plt.subplot(2, 3, 1)
srn.histplot(base.loc[base['feed'] == 'horsebean'].weight, kde = True).set(title = 'horsebean')
plt.subplot(2, 3, 2)
srn.histplot(base.loc[base['feed'] == 'casein'].weight, kde = True).set(title = 'casein')
plt.subplot(2, 3, 3)
srn.histplot(base.loc[base['feed'] == 'linseed'].weight, kde = True).set(title = 'linseed')
plt.subplot(2, 3, 4)
srn.histplot(base.loc[base['feed'] == 'meatmeal'].weight, kde = True).set(title = 'meatmeal')
plt.subplot(2, 3, 5)
srn.histplot(base.loc[base['feed'] == 'soybean'].weight, kde = True).set(title = 'soybean')
plt.subplot(2, 3, 6)
srn.histplot(base.loc[base['feed'] == 'sunflower'].weight, kde = True).set(title = 'sunflower')

# adjusts the layout so there is no overlap
plt.tight_layout()

# %% [markdown]
# # Gráfico de Dispersão com Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/tirolezzo/DataScience/main/co2.csv'
base = pd.read_csv(url)
base.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
# scatter plot using the conc and uptake attributes, grouping by type
srn.scatterplot(x = base['conc'], y = base['uptake'], hue = base.Type)
# conc = concentração de Co2
# Uptake = quanto recebeu de Co2
# Out:
# <Axes: xlabel='conc', ylabel='uptake'>

# %%
# selection of specific database records (Quebec and Mississippi)
q = base.loc[base['Type'] == 'Quebec']
m = base.loc[base['Type'] == 'Mississippi']

# %%
# Sub-graph (1 row and two columns) showing graphs of each region
plt.figure()
plt.subplot(1, 2, 1)
srn.scatterplot( x = q['conc'], y  = q['uptake']).set_title('Quebec')
plt.subplot(1, 2, 2)
srn.scatterplot( x = m['conc'], y  = m['uptake']).set_title('Mississippi')
plt.tight_layout()

# %%
# refrigerated and non-refrigerated
ch = base.loc[base ['Treatment'] == 'chilled']
nc = base.loc[base['Treatment'] == 'nonchilled']

# %%
# graph only with 'chilled' and 'nonchilled'
plt.figure()
plt.subplot(1, 2, 1)
srn.scatterplot( x = ch['conc'], y  = ch['uptake']).set_title('chilled')
plt.subplot(1, 2, 2)
srn.scatterplot( x = nc['conc'], y  = nc['uptake']).set_title('nonchilled')
plt.tight_layout()

# %%
# loading another file, esophageal cancer
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/esoph.csv')
base2 = pd.read_csv(url)
base2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
# graph between 'alcgp' and 'ncontrols' attributes
srn.catplot(x = 'alcgp', y = 'ncontrols', data = base2, jitter = False)

# %%
# graph between 'alcgp' and 'ncontrols' attributes, with grouping
srn.catplot(x = 'alcgp', y = 'ncontrols', data = base2, col = 'tobgp')

# %% [markdown]
# # Gráficos 3D

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
url = ('https://raw.githubusercontent.com/tirolezzo/DataScience/main/orchard.csv')

base = pd.read_csv(url)
base
# Out:
#     decrease  rowpos  colpos treatment
# 0         57       1       1         D
# 1         95       2       1         E
# 2          8       3       1         B
# 3         69       4       1         H
# 4         92       5       1         G
# ..       ...     ...     ...       ...
# 59        14       4       8         B
# 60        86       5       8         H
# 61        55       6       8         E
# 62         3       7       8         A
# 63        19       8       8         C
#
# [64 rows x 4 columns]

# %%
# Creation of the 3d graph, indicating the projection attribute = '3d' and passing 3 attributes (decrease, rowpos and colpos)
figura = plt.figure()
eixo = figura.add_subplot(1, 1, 1, projection = '3d')
eixo.scatter(base.decrease, base.rowpos, base.colpos)
eixo.set_xlabel('decrease')
eixo.set_ylabel('rowpos')
eixo.set_zlabel('colpos')
plt.tight_layout()

# %% [markdown]
# # Teste

# %% [markdown]
# 1. Arquivo dados.csv
#  * codigo
#  * Municipio
#  * PIB
#  * Valorempenho
# 2. Emoenho em diárias em municipios gaúchos e PIB do municipio
# 3. Execute um processo de análise exploratória para conhecimento/entendimento destes dados.
